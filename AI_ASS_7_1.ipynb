# %% [markdown]
# <a href="https://colab.research.google.com/github/jagadeesh01032005/AI-ASSIST-CODING/blob/main/AI_ASS_7_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JAGADEESH
#
# 2303A52290
#
# BATCH 44

# %% [markdown]
# TASK 1

# %%
# Bug: Missing parentheses in print statement
def greet():
    print("Hello, AI Debugging Lab!") # Corrected: Added parentheses for print function
greet()
# Out:
# Hello, AI Debugging Lab!

# %%
# Corrected code for missing parentheses in print statement
def greet_corrected():
    print("Hello, AI Debugging Lab!")

# Call the corrected function
greet_corrected()
# Out:
# Hello, AI Debugging Lab!

# %%
import io
import sys

# Test Case 1: Check if the correct message is printed
def test_greet_message():
    old_stdout = sys.stdout
    redirected_output = io.StringIO()
    sys.stdout = redirected_output
    greet_corrected()
    sys.stdout = old_stdout
    assert "Hello, AI Debugging Lab!\n" == redirected_output.getvalue()
    print("Test Case 1 Passed: Correct message printed.")

# Test Case 2: Check if the function runs without error
def test_greet_no_error():
    try:
        greet_corrected()
        assert True
        print("Test Case 2 Passed: Function runs without error.")
    except Exception as e:
        assert False, f"Test Case 2 Failed: Function raised an error: {e}"

# Test Case 3: Verify the type of the output (after capturing)
def test_greet_output_type():
    old_stdout = sys.stdout
    redirected_output = io.StringIO()
    sys.stdout = redirected_output
    greet_corrected()
    sys.stdout = old_stdout
    assert isinstance(redirected_output.getvalue(), str)
    print("Test Case 3 Passed: Output type is string.")

# Run all tests
test_greet_message()
test_greet_no_error()
test_greet_output_type()
# Out:
# Test Case 1 Passed: Correct message printed.
# Hello, AI Debugging Lab!
# Test Case 2 Passed: Function runs without error.
# Test Case 3 Passed: Output type is string.

# %%
def greet_corrected():
    print("Hello, AI Debugging Lab!")

# Call the corrected function
greet_corrected()
# Out:
# Hello, AI Debugging Lab!

# %% [markdown]
# **Reasoning**:
# The previous step introduced the need for verification. Now, I will provide the Python code for the test cases described to confirm that the `greet_corrected` function works as intended after the `SyntaxError` fix. These tests will check the output message, ensure no errors occur, and verify the output type.

# %%
import io
import sys

# Test Case 1: Check if the correct message is printed
def test_greet_message():
    old_stdout = sys.stdout
    redirected_output = io.StringIO()
    sys.stdout = redirected_output
    greet_corrected()
    sys.stdout = old_stdout
    assert "Hello, AI Debugging Lab!\n" == redirected_output.getvalue()
    print("Test Case 1 Passed: Correct message printed.")

# Test Case 2: Check if the function runs without error
def test_greet_no_error():
    try:
        greet_corrected()
        assert True
        print("Test Case 2 Passed: Function runs without error.")
    except Exception as e:
        assert False, f"Test Case 2 Failed: Function raised an error: {e}"

# Test Case 3: Verify the type of the output (after capturing)
def test_greet_output_type():
    old_stdout = sys.stdout
    redirected_output = io.StringIO()
    sys.stdout = redirected_output
    greet_corrected()
    sys.stdout = old_stdout
    assert isinstance(redirected_output.getvalue(), str)
    print("Test Case 3 Passed: Output type is string.")

# Run all tests
test_greet_message()
test_greet_no_error()
test_greet_output_type()
# Out:
# Test Case 1 Passed: Correct message printed.
# Hello, AI Debugging Lab!
# Test Case 2 Passed: Function runs without error.
# Test Case 3 Passed: Output type is string.

# %% [markdown]
# TASK 2

# %%
# Corrected: Using comparison (==) instead of assignment (=)
def check_number(n):
    if n == 10:
        return "Ten"
    else:
        return "Not Ten"

# You can now call the function, for example:
# print(check_number(10))
# print(check_number(5))

# %% [markdown]
# Now that the `check_number` function has been corrected, let's verify its functionality with three assert test cases.

# %%
# Test Case 1: Check with the number 10 (expected: 'Ten')
def test_check_number_ten():
    assert check_number(10) == "Ten", "Test Case 1 Failed: Expected 'Ten' for input 10"
    print("Test Case 1 Passed: Correctly returns 'Ten' for input 10.")

# Test Case 2: Check with a number other than 10 (expected: 'Not Ten')
def test_check_number_not_ten():
    assert check_number(5) == "Not Ten", "Test Case 2 Failed: Expected 'Not Ten' for input 5"
    print("Test Case 2 Passed: Correctly returns 'Not Ten' for input 5.")

# Test Case 3: Check with another number other than 10 (expected: 'Not Ten')
def test_check_number_another_not_ten():
    assert check_number(15) == "Not Ten", "Test Case 3 Failed: Expected 'Not Ten' for input 15"
    print("Test Case 3 Passed: Correctly returns 'Not Ten' for input 15.")

# Run all tests
test_check_number_ten()
test_check_number_not_ten()
test_check_number_another_not_ten()
# Out:
# Test Case 1 Passed: Correctly returns 'Ten' for input 10.
# Test Case 2 Passed: Correctly returns 'Not Ten' for input 5.
# Test Case 3 Passed: Correctly returns 'Not Ten' for input 15.

# %% [markdown]
# TASK 3

# %%
# Corrected: Using try-except for safe file handling
def read_file(filename):
    try:
        with open(filename, 'r') as f:
            return f.read()
    except FileNotFoundError:
        return f"Error: The file '{filename}' was not found. Please check the file path."
    except Exception as e:
        return f"An unexpected error occurred: {e}"

# The function will now handle 'nonexistent.txt' gracefully.
print(read_file("nonexistent.txt"))
# Out:
# Error: The file 'nonexistent.txt' was not found. Please check the file path.

# %% [markdown]
# TASK 4

# %%
# Test Case 1: Check if the start method returns the correct string
def test_car_start_message():
    my_car = Car()
    assert my_car.start() == "Car started", "Test Case 1 Failed: Expected 'Car started' message."
    print("Test Case 1 Passed: Car starts with the correct message.")

# Test Case 2: Check if the Car object can be instantiated without error
def test_car_instantiation():
    try:
        my_car = Car()
        assert isinstance(my_car, Car)
        print("Test Case 2 Passed: Car object can be instantiated.")
    except Exception as e:
        assert False, f"Test Case 2 Failed: Car instantiation raised an error: {e}"

# Test Case 3: Check that trying to call the *undefined* drive() method still raises an AttributeError
def test_car_no_drive_method():
    my_car = Car()
    try:
        my_car.drive()
        assert False, "Test Case 3 Failed: Calling drive() should raise an AttributeError."
    except AttributeError:
        assert True
        print("Test Case 3 Passed: Calling drive() correctly raises an AttributeError.")
    except Exception as e:
        assert False, f"Test Case 3 Failed: An unexpected error occurred when calling drive(): {e}"

# Run all tests
test_car_start_message()
test_car_instantiation()
test_car_no_drive_method()
# Out:
# Test Case 1 Passed: Car starts with the correct message.
# Test Case 2 Passed: Car object can be instantiated.
# Test Case 3 Passed: Calling drive() correctly raises an AttributeError.

# %%
# Corrected: Calling an existing method
class Car:
    def start(self):
        return "Car started"

my_car = Car()
print(my_car.start()) # Corrected: Calling the existing 'start()' method
# Out:
# Car started

# %% [markdown]
# TASK 5

# %%
# Test Case 1: Check with a string representation of an integer
def test_add_five_string_int():
    assert add_five("10") == 15, "Test Case 1 Failed: Expected 15 for input '10'"
    print("Test Case 1 Passed: Correctly adds 5 to string '10'.")

# Test Case 2: Check with an actual integer (should still work due to int() conversion)
def test_add_five_int():
    assert add_five(5) == 10, "Test Case 2 Failed: Expected 10 for input 5"
    print("Test Case 2 Passed: Correctly adds 5 to integer 5.")

# Test Case 3: Check with another string representation of an integer
def test_add_five_another_string_int():
    assert add_five("0") == 5, "Test Case 3 Failed: Expected 5 for input '0'"
    print("Test Case 3 Passed: Correctly adds 5 to string '0'.")

# Run all tests
test_add_five_string_int()
test_add_five_int()
test_add_five_another_string_int()
# Out:
# Test Case 1 Passed: Correctly adds 5 to string '10'.
# Test Case 2 Passed: Correctly adds 5 to integer 5.
# Test Case 3 Passed: Correctly adds 5 to string '0'.

# %%
# Corrected: TypeError due to mixing string and integer - using type casting
def add_five(value):
    # Solution 1: Type casting 'value' to an integer for arithmetic addition
    return int(value) + 5

print(add_five("10"))

# Alternative for string concatenation (if that were the intent):
# def add_five_str(value):
#     # Solution 2: Type casting '5' to a string for string concatenation
#     return value + str(5)
# print(add_five_str("10")) # This would print '105'
# Out:
# 15
